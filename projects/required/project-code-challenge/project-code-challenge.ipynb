# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Python Coding Exercises
#
# _Authors: Joseph Nelson (DC) _
#
# ---

# %% [markdown]
# The following code challenges are drawn from common exercises used in technical interviews.
#
# Please note that there may be several ways to approach each challenge. If you get stuck, try mapping out your approach in pseudocode first. Finally, while solutions to problems like these may be found online, remember that if you copy/paste code that you can't explain, you'll be missing out on the point of the project. The only way to truly learn a new skill is through practice, trial, and error - we can only help you improve by understanding where you are having trouble.

# %% [markdown]
# ### Challenge 1: Largest Palindrome
# A palindromic number reads the same both ways. For example, 1234321 is a palindrome. The largest palindrome made from the product of two two-digit numbers is 9009 = 91 × 99. Find the largest palindrome made from the product of two three-digit numbers. Afterward, write a brief explanation walking through your code's logic in markdown.

# %%
three_digit_numbers = list(range(100, 1000))
three_digit_numbers
# Out:
# [100,
#  101,
#  102,
#  103,
#  104,
#  105,
#  106,
#  107,
#  108,
#  109,
#  110,
#  111,
#  112,
#  113,
#  114,
#  115,
#  116,
#  117,
#  118,
#  119,
#  120,
#  121,
#  122,
#  123,
#  124,
#  125,
#  126,
#  127,
#  128,
#  129,
#  130,
#  131,
#  132,
#  133,
#  134,
#  135,
#  136,
#  137,
#  138,
#  139,
#  140,
#  141,
#  142,
#  143,
#  144,
#  145,
#  146,
#  147,
#  148,
#  149,
#  150,
#  151,
#  152,
#  153,
#  154,
#  155,
#  156,
#  157,
#  158,
#  159,
#  160,
#  161,
#  162,
#  163,
#  164,
#  165,
#  166,
#  167,
#  168,
#  169,
#  170,
#  171,
#  172,
#  173,
#  174,
#  175,
#  176,
#  177,
#  178,
#  179,
#  180,
#  181,
#  182,
#  183,
#  184,
#  185,
#  186,
#  187,
#  188,
#  189,
#  190,
#  191,
#  192,
#  193,
#  194,
#  195,
#  196,
#  197,
#  198,
#  199,
#  200,
#  201,
#  202,
#  203,
#  204,
#  205,
#  206,
#  207,
#  208,
#  209,
#  210,
#  211,
#  212,
#  213,
#  214,
#  215,
#  216,
#  217,
#  218,
#  219,
#  220,
#  221,
#  222,
#  223,
#  224,
# ...

# %%
import collections
biggest_palindrome = 0
products = collections.defaultdict(list)
for a in three_digit_numbers:
    for b in three_digit_numbers:
        the_number = a * b
        the_number_as_a_string = str(the_number)
        the_number_reversed = the_number_as_a_string[::-1]
        if the_number_as_a_string == the_number_reversed:
            if the_number >= biggest_palindrome:
                biggest_palindrome = the_number
                products[the_number] = products[the_number] + [(a,b)]
print(biggest_palindrome, products[biggest_palindrome])
# Out:
# 906609 [(913, 993), (993, 913)]

# %%
biggest_palindrome = 0
products = {}
for a in three_digit_numbers:
    for b in three_digit_numbers:
        the_number = a * b
        the_number_as_a_string = str(the_number)
        the_number_reversed = the_number_as_a_string[::-1]
        if the_number_as_a_string == the_number_reversed:
            if the_number >= biggest_palindrome:
                biggest_palindrome = the_number
                if the_number not in products:
                    products[the_number] = []
                products[the_number] = products[the_number] + [(a,b)]
print(biggest_palindrome, products[biggest_palindrome])
# Out:
# 906609 [(913, 993), (993, 913)]

# %%
# %%time
biggest_palindrome = 0
products = {}
for a in three_digit_numbers:
    for b in range(a,1000):
        the_number = a * b
        the_number_as_a_string = str(the_number)
        the_number_reversed = the_number_as_a_string[::-1]
        if the_number_as_a_string == the_number_reversed:
            if the_number >= biggest_palindrome:
                biggest_palindrome = the_number
                products[the_number] = products.get(the_number, []) + [(a,b)]
print(biggest_palindrome, products[biggest_palindrome])
# Out:
# 906609 [(913, 993)]
# Wall time: 329 ms

# %%
# %%time

# Doesn't quite work...
found_one = False
for a in range(999, 100, -1):
    for b in range(999, a, -1):
        the_number = a * b
        the_number_as_a_string = str(the_number)
        the_number_reversed = the_number_as_a_string[::-1]
        if the_number_as_a_string == the_number_reversed:
            print(the_number, a, b)
            found_one = True
            break
    if found_one:
        break
# Out:
# 888888 924 962
# Wall time: 2 ms

# %%
# %%time
sorted([(a*b, a, b) for a in three_digit_numbers for b in range(a,1000)
  if str(a*b) == str(a*b)[::-1]
])[-1]
# Out:
# Wall time: 360 ms
# (906609, 913, 993)

# %% [markdown]
# Answering a question about collections (the second answer above)

# %%
)c = collections.defaultdict(list)
c[1]
# Out:
# []

# %%
d = {}
d[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-4992413a82b9> in <module>
#       1 d = {}
# ----> 2 d[1]
#
# KeyError: 1

# %%
c[1] = ['a', 'b', 'c']
c[1]
# Out:
# ['a', 'b', 'c']

# %%
d[1] = ['a', 'b', 'c']
d[1]
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# ### Challenge 2: Summation of Primes
# The sum of the primes below 10 is 2 + 3 + 5 + 7 = 17. Find the sum of all the primes below 2,000. Afterward, write a brief explanation walking through your code's logic in markdown.

# %%
# %%time
primes = [2,3,5]
for i in range(6, 2000):
    is_prime = True
    for j in range(2,i):
        if i%j == 0:
            is_prime = False
            break
    if is_prime:
        primes.append(i)
sum(primes)
# Out:
# Wall time: 49.5 ms
# 277050

# %%
# %%time
primes = [2,3,5]
for i in range(6, 2000):
    is_prime = True
    for j in primes:
        if i%j == 0:
            is_prime = False
            break
    if is_prime:
        primes.append(i)
sum(primes)
# Out:
# Wall time: 7.5 ms
# 277050

# %%
# %%time
def primes():
    yield 2
    yield 3
    yield 5
    for i in range(6, 2000):
        is_prime = True
        for j in range(2,i):
            if i%j == 0:
                is_prime = False
                break
        if is_prime:
            yield i

sum(primes())
# Out:
# Wall time: 24 ms
# 277050

# %% [markdown]
# ### Challenge 3: Multiples of 3 and 5
# If we list all of the natural numbers below 10 that are multiples of 3 or 5, we get 3, 5, 6, and 9. The sum of these multiples is 23. Find the sum of all the multiples of 3 and 5 below 1,000. Afterward, write a brief explanation walking through your code's logic in markdown.

# %%
running_sum = 0
for i in range(1000):
    if i % 3 == 0 or i % 5 == 0:
        running_sum += i
running_sum
# Out:
# 233168

# %% [markdown]
# ### Challenge 4: String Compressor
# Implement a method to perform basic string compression using the counts of repeated characters. (This is called run-length encoding.) For example, the string "aabcccccaaa" would become a2b1c5a3. If the “compressed” string would not become smaller than the original string, your method should return the original string. You can assume the string has only uppercase and lowercase letters (a–z). Specify whether your solution is case sensitive or case insensitive and what you would need to change to make it the other. Afterward, write a brief explanation walking through your code's logic in markdown.

# %%
def _compressor(s):
    if len(s) == 0:
        return ''
    if len(s) == 1:
        return s[0] + "1"
    if s[0] != s[1]:
        return s[0] + "1" + _compressor(s[1:])
    for i in range(1,len(s)):
        if s[0] == s[i]:
            continue
        return s[0] + str(i) + _compressor(s[i:])
    return s[0] + str(len(s))

def compressor(s):
    c = _compressor(s)
    if len(c) < len(s):
        return c
    else:
        return s

# %%
compressor("aabcccccaaa")
# Out:
# 'a2b1c5a3'

# %%
compressor("xyz")
# Out:
# 'xyz'

# %% [markdown]
# ### *BONUS* Challenge: FizzBuzz
# Write a program that prints all of the numbers from 1 to 100. For multiples of 3, instead of the number, print "Fizz;" for multiples of 5, print "Buzz." For numbers that are multiples of both 3 and 5, print "FizzBuzz." Afterward, write a brief explanation walking through your code's logic in markdown.
